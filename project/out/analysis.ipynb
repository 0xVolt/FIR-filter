# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('../data.csv')

# %%
df
# Out:
#      Raw Input   Filtered Output
# 0     0.252056          0.100823
# 1     0.134022          0.129226
# 2     0.266341          0.197154
# 3     0.286638          0.246568
# 4     0.336285          0.299779
# ..         ...               ...
# 995   0.124872          0.229571
# 996   0.264884          0.241640
# 997   0.144261          0.205084
# 998   0.135569          0.180245
# 999   0.175461          0.172439
#
# [1000 rows x 2 columns]

# %%
df['Raw Input']
# Out:
# 0      0.252056
# 1      0.134022
# 2      0.266341
# 3      0.286638
# 4      0.336285
#          ...
# 995    0.124872
# 996    0.264884
# 997    0.144261
# 998    0.135569
# 999    0.175461
# Name: Raw Input, Length: 1000, dtype: float64

# %%
plt.xlabel('Time')
plt.ylabel('Amplitude')

plt.plot(df)
plt.legend(['Raw Input', 'Filtered Output'], loc='lower right')

plt.grid()
