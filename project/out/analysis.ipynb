# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('../data.csv')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In [17], line 1
# ----> 1 df = pd.read_csv('../data.csv')
#
# File ~/.local/lib/python3.8/site-packages/pandas/util/_decorators.py:211, in deprecate_kwarg.<locals>._deprecate_kwarg.<locals>.wrapper(*args, **kwargs)
#     209     else:
#     210         kwargs[new_arg_name] = new_arg_value
# --> 211 return func(*args, **kwargs)
#
# File ~/.local/lib/python3.8/site-packages/pandas/util/_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
#     330     )
# --> 331 return func(*args, **kwargs)
#
# ...

# %%
df
# Out:
#     Raw Input   Filtered Output
# 0    0.252056          0.100823
# 1    0.274749          0.185517
# 2    0.543947          0.350415
# 3    0.693523          0.520749
# 4    0.861279          0.701436
# ..        ...               ...
# 95   0.984298          1.078745
# 96   0.707315          0.938666
# 97   0.698420          0.839941
# 98   0.514282          0.702176
# 99   0.429725          0.585805
#
# [100 rows x 2 columns]

# %%
df['Raw Input']
# Out:
# 0     0.252056
# 1     0.274749
# 2     0.543947
# 3     0.693523
# 4     0.861279
#         ...
# 95    0.984298
# 96    0.707315
# 97    0.698420
# 98    0.514282
# 99    0.429725
# Name: Raw Input, Length: 100, dtype: float64

# %%
plt.xlabel('Time')
plt.ylabel('Amplitude')

plt.plot(df)
plt.legend(['Raw Input', 'Filtered Output'], loc='lower right')

plt.grid()
